# %%
from Poly_Kernel_Testing import Poly_Kernel_Testing

# %%
a = Poly_Kernel_Testing("/home/moe/Desktop/dof/data_processing/output_with_rnn.csv","/home/moe/Desktop/dof/datasets/dataset _Main.csv",0.2,2)
b = a.inliers()
print(b)
a.draw(b)
#### RNN
# Out:
# [np.float64(86.14535418583257), np.float64(85.62557497700092), np.float64(87.9)]

# %%
a = Poly_Kernel_Testing("/home/moe/Desktop/dof/data_processing/output_with_transformer.csv","/home/moe/Desktop/dof/datasets/dataset _Main.csv",0.2,2)
b = a.inliers()
print(b)
a.draw(b)
#### Transformers
# Out:
# [np.float64(86.14535418583257), np.float64(85.62557497700092), np.float64(84.89999999999999)]

# %%
a = Poly_Kernel_Testing("/home/moe/Desktop/dof/data_processing/output_with_waveNet.csv","/home/moe/Desktop/dof/datasets/dataset _Main.csv",0.2,2)
b = a.inliers()
print(b)
a.draw(b)

#### WaveNet
# Out:
# [np.float64(86.14535418583257), np.float64(85.62557497700092), np.float64(69.19999999999999)]
